# %%
import exp_utils

#Folder containing all experiment files
fileFolder = './log/'
#Experiment 1 - Simultaneously Learning agents


source1 = fileFolder + 'QLearning-NoneCurriculum'
source2 = fileFolder + 'RewardShapingQLearning-SvetlikCurriculum'
source3 = fileFolder + 'VFReuseQLearning-SvetlikCurriculum'
source4 = fileFolder + 'VFReuseQLearning-ObjectOrientedCurriculum'
source5 = fileFolder + 'PITAMQLearning-ObjectOrientedCurriculum'
source6 = fileFolder + 'PITAMRSQLearning-ObjectOrientedCurriculum'


name1 = 'No Transfer'
name2 = 'Svetlik - RS'
name3 = 'Svetlik - VF'
name4 = 'OO - VF'
name5 = 'OO - PITAM'
name6 = 'OO - RS'
#name6 = 'Scratch'


#Prepare intermediary files with experiment's summary.
exp_utils.collect_experiment_data(source1, runs = 100)
exp_utils.summarize_experiment_data(source1)
exp_utils.collect_experiment_data(source2, runs = 100)
exp_utils.summarize_experiment_data(source2)
exp_utils.collect_experiment_data(source3, runs =100)
exp_utils.summarize_experiment_data(source3)
exp_utils.collect_experiment_data(source4, runs =100)
exp_utils.summarize_experiment_data(source4)
exp_utils.collect_experiment_data(source5, runs =100)
exp_utils.summarize_experiment_data(source5)
exp_utils.collect_experiment_data(source6, runs =100)
exp_utils.summarize_experiment_data(source6)
#exp_utils.collect_experiment_data(source3, runs = 50,compact=True)
#exp_utils.summarize_experiment_data(source3,compact=True)
#exp_utils.cummulative_experiment_data(source3,compact=True)
##exp_utils.collect_experiment_data(source4, runs = 50,compact=True)
#exp_utils.summarize_experiment_data(source4,compact=True)
#exp_utils.cummulative_experiment_data(source4,compact=True)
#exp_utils.collect_experiment_data(source5, runs = 50,compact=True)
#exp_utils.summarize_experiment_data(source5,compact=True)
#exp_utils.cummulative_experiment_data(source5,compact=True)
#exp_utils.collect_experiment_data(source6, runs = 50,compact=True)
#exp_utils.summarize_experiment_data(source6,compact=True)
#exp_utils.cummulative_experiment_data(source6,compact=True)

#Intervals for zoomed averages
xMinPerc = 4500
xMaxPerc = 5000
yMinPerc = 64
yMaxPerc = 75

#Intervals for Time for Goal graphs
xMinStep = 3000
xMaxStep = 5000
yMinStep = 95
yMaxStep = 110

xMinStep2 = 0
xMaxStep2 = 1000
yMinStep2 = 30
yMaxStep2 = 110


printCI = True


exp_utils.draw_graph(source1=source1, name1=name1, source2=source2,name2=name2,source3=source3,name3=name3,source4=source4,name4=name4,source5=source5,name5=name5,source6=source6,name6=name6,
                     ci=printCI,xMin = 10000,xMax=23000,yMin=-20, yMax = 20)
exp_utils.draw_graph(source1=source1, name1=name1, source2=source2,name2=name2,source3=source3,name3=name3,source4=source4,name4=name4,source5=source5,name5=name5,source6=source6,name6=name6,
                     ci=printCI,what='__SUMMARY_steps')#,xMax = 10000, xMin=0)
# Out:
# Could use 100 runs from expected 100
# Could use 100 runs from expected 100
# Could use 100 runs from expected 100
# Could use 100 runs from expected 100
# Could use 100 runs from expected 100
# Could use 100 runs from expected 100
